# %% [markdown]
# <a href="https://colab.research.google.com/github/soupriyaaa/ml-lab-assignments/blob/main/01-plot/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/drive/MyDrive/rooms.csv')
print(df)
# Out:
#     Rooms  Area (sq ft)  Price (INR)
# 0       2           850       147500
# 1       4          1500       245000
# 2       6          2500       415000
# 3       3          1000       180000
# 4       4          1300       235000
# 5       2           700       125000
# 6       1           500        85000
# 7       5          2160       344000
# 8       3          1250       207500
# 9       2           730       123500
# 10      3           900       155000
# 11      2           600       110000
# 12      2           850       144500
# 13      1           350        62500
# 14      4          1400       250000
# 15      3          1200       200000
# 16      1           450        77500
# 17      3          1300       220000
# 18      2           560       104000
# 19      3           790       138500

# %%
plt.scatter(df["Rooms"], df["Area (sq ft)"], color="purple", marker="*")
plt.xlabel("Number of Rooms")
plt.ylabel("Area (sq ft)")
plt.title("Scatter Plot: Rooms vs Area")
plt.grid(True)
plt.show()

# %%
print("Number of missing values per column:")
print(df.isnull().sum())
# Out:
# Number of missing values per column:
# Rooms           0
# Area (sq ft)    0
# Price (INR)     0
# dtype: int64

# %%
print("Mean:\n", df.mean(numeric_only=True))
print("\nMedian:\n", df.median(numeric_only=True))
print("\nStandard Deviation:\n", df.std(numeric_only=True))
# Out:
# Mean:
#  Rooms                2.8
# Area (sq ft)      1044.5
# Price (INR)     178475.0
# dtype: float64
#
# Median:
#  Rooms                3.0
# Area (sq ft)       875.0
# Price (INR)     151250.0
# dtype: float64
#
# Standard Deviation:
#  Rooms               1.321881
# Area (sq ft)      554.365213
# Price (INR)     89406.004008
# dtype: float64

# %%
print("\nDataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rooms         20 non-null     int64
#  1   Area (sq ft)  20 non-null     int64
#  2   Price (INR)   20 non-null     int64
# dtypes: int64(3)
# memory usage: 612.0 bytes
# None
